# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [raw]
# Matplotlib is a widely-used Python library for creating static, interactive, and animated visualizations in a wide range of formats. It provides a versatile set of tools for creating various types of plots, graphs, and charts. Matplotlib is often used for data visualization and exploration, making it easier to understand trends, patterns, and relationships within the data.

# %% [raw]
# -Line Plot
# -Scatter Plot
# -Bar Plot
# -Histogram
# -Pie Chart

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %% [raw]
# Scatter Plot: A scatter plot is used to display the relationship between two variables as individual data points. Each point represents a data observation, making it useful for identifying patterns or correlations.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.title("Scatter plot table")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %% [raw]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [raw]
# Ans. In Matplotlib, a subplot refers to a single plot or graph that is part of a larger grid of plots. It allows you to create multiple plots within a single figure, arranging them in rows and columns. Subplots are a convenient way to display multiple visualizations side by side, making it easier to compare and contrast different aspects of your data.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 100, 200, 300, 400, 500])

plt.subplot(2,3,1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([50, 20, 40, 20, 60, 70])

plt.subplot(2,3,2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50, 60])

plt.subplot(2,3,3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2,3,4)
plt.plot(x,y)

# %% [raw]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [raw]
# Ans. A bar plot, also known as a bar chart, is a type of data visualization used to display and compare categorical data using rectangular bars. Each bar represents a category, and the height or length of the bar corresponds to the value of the category it represents. Bar plots are particularly useful for showing comparisons between different categories or groups.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.figure(figsize=(4,3))
plt.bar(company, profit)
plt.xlabel("Company")
plt.ylabel("Profit")
# Out:
# Text(0, 0.5, 'Profit')

# %%
plt.figure(figsize=(4,3))
plt.barh(company, profit)
plt.xlabel("Profit")
plt.ylabel("Company")
# Out:
# Text(0, 0.5, 'Company')

# %% [raw]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [raw]
# Ans. A box plot, also known as a box-and-whisker plot, is a type of data visualization that provides a concise summary of the distribution of a dataset. It displays key statistical measures, such as the median, quartiles, and potential outliers, in a way that allows you to quickly assess the overall shape and variability of the data.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data = [box1,box2]

# %%
plt.boxplot(data, labels = ['box1','box2'])
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')
